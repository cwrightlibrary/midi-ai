# %% [markdown]
# # midiAI
#
# Let's examine our first `.mid` file, `data/solar.mid`.

# %%
import os
from mido import MidiFile

mid = MidiFile("data/solar.mid", clip=True)

for msg in mid.tracks[4]:
	print(msg)

for track in range(0, len(mid.tracks)):
	if track != 4:
		mid.tracks.remove(track)

print(mid)
# Out:
# MetaMessage('midi_port', port=0, time=0)
# MetaMessage('track_name', name='Guitar', time=0)
# program_change channel=3 program=26 time=0
# control_change channel=3 control=7 value=127 time=0
# control_change channel=3 control=10 value=67 time=0
# control_change channel=3 control=91 value=107 time=0
# control_change channel=3 control=93 value=0 time=0
# note_on channel=3 note=72 velocity=127 time=92
# note_on channel=3 note=72 velocity=0 time=151
# note_on channel=3 note=71 velocity=127 time=10
# note_on channel=3 note=71 velocity=0 time=46
# note_on channel=3 note=74 velocity=127 time=64
# note_on channel=3 note=74 velocity=0 time=71
# note_on channel=3 note=72 velocity=127 time=16
# note_on channel=3 note=72 velocity=0 time=57
# note_on channel=3 note=67 velocity=127 time=65
# note_on channel=3 note=67 velocity=0 time=344
# note_on channel=3 note=69 velocity=127 time=8
# note_on channel=3 note=70 velocity=127 time=55
# note_on channel=3 note=69 velocity=0 time=8
# ...
